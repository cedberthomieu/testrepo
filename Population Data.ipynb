# %% [markdown]
# ### Changes in World Population Since 1960
#
# The data shown below shows how the
# [world's population](https://www.worldometers.info/world-population/world-population-by-year/)
# has more than doubled since 1960.
#
# This has [implications](https://ugc.berkeley.edu/background-content/population-growth/)
# in a variety of areas including:
#
# * Increased extraction of environmental resources.
# * Increased fossil fuel usage.
# * Increased disease transmission.
# * Increased transportation of invasive species.
#
# **The data below shows the population each decade since 1960:**

# %%
# decades = [1960, 1970, 1980, 1990, 2000, 2010, 2020]

# World population (billions)
# population = [3, 3.7, 4.4, 5.3, 6.1, 7.0, 7.8]

decades = [1975, 1990, 2000, 2010, 2020]
population = [4.4, 5.3, 6.1, 7.0, 7.8]

# %%
# !python -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\dev\jupyterlab_project\jl_venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

plt.plot(decades, population,color='r')

plt.xlabel("Year")
plt.ylabel("Population (Billion)")
plt.title("World Population")

plt.show()
