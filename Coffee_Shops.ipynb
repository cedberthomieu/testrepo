# %%
import cplex
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import cplex
#
# File C:\dev\jupyterlab_project\tutorial_project\cplex\__init__.py:44
#      41 import os
#      42 import weakref
# ---> 44 from .aborter import Aborter
#      45 from . import callbacks
#      46 from . import model_info
#
# File C:\dev\jupyterlab_project\tutorial_project\cplex\aborter.py:13
#       1 # --------------------------------------------------------------------------
#       2 # File: aborter.py
#       3 # ---------------------------------------------------------------------------
#    (...)
#      10 # IBM Corp.
#      11 # --------------------------------------------------------------------------
#      12 """Aborter API"""
# ---> 13 from ._internal import _procedural as _proc
#      16 class Aborter():
#      17     """Gracefully terminates the solve and tuning methods of CPLEX.
#      18
#      19     You can pass an instance of this class to one or more Cplex objects.
#    (...)
#      22     method of the Cplex object.
#      23     """
#
# File C:\dev\jupyterlab_project\tutorial_project\cplex\_internal\__init__.py:20
#      18 from . import _aux_functions
#      19 from . import _baseinterface
# ---> 20 from . import _list_array_utils
#      21 from . import _ostream
#      22 from . import _procedural
#
# File C:\dev\jupyterlab_project\tutorial_project\cplex\_internal\_list_array_utils.py:14
#      12 """Functions to convert Python lists to C arrays."""
#      13 from contextlib import contextmanager
# ---> 14 from . import _pycplex as CPX
#      16 # int_list_to_C_array    = CPX.int_list_to_C_array
#      17 # double_list_to_C_array = CPX.double_list_to_C_array
#      20 def int_list_to_array(inputlist):
#
# File C:\dev\jupyterlab_project\tutorial_project\cplex\_internal\_pycplex.py:13
#      11 # Import the low-level C/C++ module
#      12 if __package__ or '.' in __name__:
# ---> 13     from . import _pycplex_platform
#      14 else:
#      15     import _pycplex_platform
#
# File C:\dev\jupyterlab_project\tutorial_project\cplex\_internal\_pycplex_platform.py:19
#      16 ERROR_STRING = "CPLEX 22.1.1.0 is not compatible with this version of Python."
#      18 if platform.system() in ('Darwin', 'Linux', 'AIX', 'Windows', 'Microsoft'):
# ---> 19     from cplex._internal.py311_cplex2211 import *
#      21 else:
#      22     raise Exception("The CPLEX Python API is not supported on this platform.")
#
# ImportError: DLL load failed while importing py311_cplex2211: Le module spécifié est introuvable.

# %%
import sys
import docplex.mp

# %%
# Store longitude, latitude and street crossing name of each public library location.
class XPoint(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __str__(self):
        return "P(%g_%g)" % (self.x, self.y)

class NamedPoint(XPoint):
    def __init__(self, name, x, y):
        XPoint.__init__(self, x, y)
        self.name = name
    def __str__(self):
        return self.name

# %%
try:
    import geopy.distance
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip install geopy 
    else:
        # !pip install --user geopy
# Out:
# ERROR: Can not perform a '--user' install. User site-packages are not visible in this virtualenv.

# %%
# Simple distance computation between 2 locations.
from geopy.distance import great_circle
 
def get_distance(p1, p2):
    return great_circle((p1.y, p1.x), (p2.y, p2.x)).miles

# %%
def build_libraries_from_url(url, name_pos, lat_long_pos):
    import requests
    import json

    r = requests.get(url)
    myjson = json.loads(r.text, parse_constant='utf-8')
    myjson = myjson['data']

    libraries = []
    k = 1
    for location in myjson:
        uname = location[name_pos]
        try:
            latitude = float(location[lat_long_pos][1])
            longitude = float(location[lat_long_pos][2])
        except TypeError:
            latitude = longitude = None
        try:
            name = str(uname)
        except:
            name = "???"
        name = "P_%s_%d" % (name, k)
        if latitude and longitude:
            cp = NamedPoint(name, longitude, latitude)
            libraries.append(cp)
            k += 1
    return libraries

# %%
libraries = build_libraries_from_url('https://data.cityofchicago.org/api/views/x8fc-8rcq/rows.json?accessType=DOWNLOAD',
                                   name_pos=10,
                                   lat_long_pos=16)

# %%
print("There are %d public libraries in Chicago" % (len(libraries)))
# Out:
# There are 81 public libraries in Chicago

# %%
import cplex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import cplex
#
# ModuleNotFoundError: No module named 'cplex'

# %%
print(libraries[0])
# Out:
# P_3710 E. 106th St._1

# %%
libraries.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 libraries.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
nb_shops = 5
print("We would like to open %d coffee shops" % nb_shops)
# Out:
# We would like to open 5 coffee shops

# %%
import folium
map_osm = folium.Map(location=[41.878, -87.629], zoom_start=11)
for library in libraries:
    lt = library.y
    lg = library.x
    folium.Marker([lt, lg]).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c89aca0db6371d2955cae6453c996bcd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c89aca0db6371d2955cae6453c996bcd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c89aca0db6371d2955cae6453c996bcd = L.map(
#                 &quot;map_c89aca0db6371d2955cae6453c996bcd&quot;,
#                 {
#                     center: [41.878, -87.629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35b3b4f25093baaebbfbb1f870d04433 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_35b3b4f25093baaebbfbb1f870d04433.addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_31604f21d7924e39f00861c56d2611e2 = L.marker(
#                 [41.70283443594318, -87.61428978448026],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_e75506a42ed9a783aed57ef9e587c8ba = L.marker(
#                 [41.97557881655979, -87.71361314512697],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_c0093383210802479caacab0f4552940 = L.marker(
#                 [41.746393038286826, -87.5860053710736],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_c857fcb304b5c282034e9830abdf67a1 = L.marker(
#                 [41.73244482025524, -87.65772892721816],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_d088b7491071f4f1719d336d6082ea04 = L.marker(
#                 [41.897484072390675, -87.62337776811282],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_087254649288db8bf882f8f12709afc1 = L.marker(
#                 [41.86946341218242, -87.66072612668584],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_58d56e43f8eca45cb554cf28acfe9164 = L.marker(
#                 [41.997213372156295, -87.76211751799003],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_eaf061d2304c0efe88f78b63b8c2db1c = L.marker(
#                 [41.78202569697298, -87.63738794358196],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_215815f16853fcb86ebd04c17d5a5907 = L.marker(
#                 [41.99095923823291, -87.660442745415],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_ea3b63fc700b73b271c43c1b28dbf0bf = L.marker(
#                 [41.909444834238485, -87.76898326931509],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_779c49ce03364baab0bbd3e6aba925da = L.marker(
#                 [41.81634394084193, -87.64256827550598],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_f7ff453a1713752d0e206e6a34911e4a = L.marker(
#                 [41.8327976771251, -87.64629980794813],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_838a4ba09b04ae65efac4fc61b58e2e3 = L.marker(
#                 [41.88108555559726, -87.67923504553734],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_a7d0fd502f65a516936ab2b7a4b3d0f3 = L.marker(
#                 [41.93883597361448, -87.75467117455794],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_1e12431099a64a1568290ab7c3a72558 = L.marker(
#                 [41.7510184591363, -87.61495065361933],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_cc0b7e3accf4327892bbc26e21b23b48 = L.marker(
#                 [41.76239541819689, -87.60051216643727],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_6f724deeb28e27d4b3116ad83da0f206 = L.marker(
#                 [41.74928543110801, -87.72440869132882],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_18c75414453465196e93f05b0d7d4f95 = L.marker(
#                 [41.65719847558056, -87.59883829075173],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_5695c695fb81b877077b36f8d2fa90ef = L.marker(
#                 [41.77875389246921, -87.72374295317714],
#                 {}
#             ).addTo(map_c89aca0db6371d2955cae6453c996bcd);
#
#
#             var marker_a40e15a5ee0f

# %%
from docplex.mp.environment import Environment
env = Environment()
env.print_information()
# Out:
# * system is: Windows 64bit
# * Python version 3.12.2, located at: C:\dev\jupyterlab_project\jl_venv\Scripts\python.exe
# * docplex is present, version is 2.25.236
# * CPLEX library is not available
# * pandas is present, version is 2.2.0

# %%
from docplex.mp.model import Model

mdl = Model("coffee shops")

# %%
BIGNUM = 999999999

# Ensure unique points
libraries = set(libraries)
# For simplicity, let's consider that coffee shops candidate locations are the same as libraries locations.
# That is: any library location can also be selected as a coffee shop.
coffeeshop_locations = libraries

# Decision vars
# Binary vars indicating which coffee shop locations will be actually selected
coffeeshop_vars = mdl.binary_var_dict(coffeeshop_locations, name="is_coffeeshop")
#
# Binary vars representing the "assigned" libraries for each coffee shop
link_vars = mdl.binary_var_matrix(coffeeshop_locations, libraries, "link")

# %%
for c_loc in coffeeshop_locations:
    for b in libraries:
        if get_distance(c_loc, b) >= BIGNUM:
            mdl.add_constraint(link_vars[c_loc, b] == 0, "ct_forbid_{0!s}_{1!s}".format(c_loc, b))

# %%
mdl.add_constraints(link_vars[c_loc, b] <= coffeeshop_vars[c_loc]
                   for b in libraries
                   for c_loc in coffeeshop_locations)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 6642
#    - binary=6642, integer=0, continuous=0
#  - number of constraints: 6561
#    - linear=6561
#  - parameters: defaults
#  - objective: none

# %%
mdl.add_constraints(mdl.sum(link_vars[c_loc, b] for c_loc in coffeeshop_locations) == 1
                   for b in libraries)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 6642
#    - binary=6642, integer=0, continuous=0
#  - number of constraints: 6642
#    - linear=6642
#  - parameters: defaults
#  - objective: none

# %%
# Total nb of open coffee shops
mdl.add_constraint(mdl.sum(coffeeshop_vars[c_loc] for c_loc in coffeeshop_locations) == nb_shops)

# Print model information
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 6642
#    - binary=6642, integer=0, continuous=0
#  - number of constraints: 6643
#    - linear=6643
#  - parameters: defaults
#  - objective: none

# %%
# Minimize total distance from points to hubs
total_distance = mdl.sum(link_vars[c_loc, b] * get_distance(c_loc, b) for c_loc in coffeeshop_locations for b in libraries)
mdl.minimize(total_distance)

# %%
print("# coffee shops locations = %d" % len(coffeeshop_locations))
print("# coffee shops           = %d" % nb_shops)

assert mdl.solve(), "!!! Solve of the model fails"
# Out:
# # coffee shops locations = 81
# # coffee shops           = 5
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# Cell In[32], line 4
#       1 print("# coffee shops locations = %d" % len(coffeeshop_locations))
#       2 print("# coffee shops           = %d" % nb_shops)
# ----> 4 assert mdl.solve(), "!!! Solve of the model fails"
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\model.py:4835, in Model.solve(self, **kwargs)
#    4833     return self._solve_local(context, used_clean_before_solve, parameter_sets)# lex_timelimits, lex_mipgaps)
#    4834 else:
# -> 4835     return self.fatal("Cannot solve model: no CPLEX runtime found.")
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\model.py:1080, in Model.fatal(self, msg, *args)
#    1079 def fatal(self, msg, *args):
# -> 1080     self._error_handler.fatal(msg, args)
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\error_handler.py:210, in AbstractErrorHandler.fatal(self, msg, args)
#     208 resolved_message = resolve_pattern(msg, args)
#     209 docplex_error_stop_here()
# --> 210 raise DOcplexException(resolved_message)
#
# DOcplexException: Cannot solve model: no CPLEX runtime found.

# %%
total_distance = mdl.objective_value
open_coffeeshops = [c_loc for c_loc in coffeeshop_locations if coffeeshop_vars[c_loc].solution_value == 1]
not_coffeeshops = [c_loc for c_loc in coffeeshop_locations if c_loc not in open_coffeeshops]
edges = [(c_loc, b) for b in libraries for c_loc in coffeeshop_locations if int(link_vars[c_loc, b]) == 1]

print("Total distance = %g" % total_distance)
print("# coffee shops  = {0}".format(len(open_coffeeshops)))
for c in open_coffeeshops:
    print("new coffee shop: {0!s}".format(c))
# Out:
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 total_distance = mdl.objective_value
#       2 open_coffeeshops = [c_loc for c_loc in coffeeshop_locations if coffeeshop_vars[c_loc].solution_value == 1]
#       3 not_coffeeshops = [c_loc for c_loc in coffeeshop_locations if c_loc not in open_coffeeshops]
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\model.py:5371, in Model.objective_value(self)
#    5363 @property
#    5364 def objective_value(self):
#    5365     """ This property returns the value of the objective expression in the solution of the last solve.
#    5366     In case of a multi-objective, only the value of the first objective is returned
#    5367
#    5368     Raises an exception if the model has not been solved successfully.
#    5369
#    5370     """
# -> 5371     self._check_has_solution()
#    5372     return self._objective_value()
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\model.py:5187, in Model._check_has_solution(self)
#    5185 if self._solution is None:
#    5186     if self._solve_details is None:
# -> 5187         self.fatal("Model<{0}> has not been solved yet", self.name)
#    5188     else:
#    5189         self.fatal("Model<{0}> did not solve successfully", self.name)
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\model.py:1080, in Model.fatal(self, msg, *args)
#    1079 def fatal(self, msg, *args):
# -> 1080     self._error_handler.fatal(msg, args)
#
# File C:\dev\jupyterlab_project\jl_venv\Lib\site-packages\docplex\mp\error_handler.py:210, in AbstractErrorHandler.fatal(self, msg, args)
#     208 resolved_message = resolve_pattern(msg, args)
#     209 docplex_error_stop_here()
# --> 210 raise DOcplexException(resolved_message)
#
# DOcplexException: Model<coffee shops> has not been solved yet
